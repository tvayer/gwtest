# %% [markdown]
# # Classification on toy trees

# %%
import seaborn as sns
import numpy as np
import os,sys
module_path = os.path.abspath(os.path.join('/Users/vayer/Documents/OT/Python/GW_tests/'))
if module_path not in sys.path:
    sys.path.append(module_path)
from graph import *
import copy

# %%
graph=Graph()

# %%
graph.add_vertex(1)
graph.add_vertex(2)

# %%
graph.nodes()
# Out:
# [1, 2]

# %%
graph.binary_link(1,2)

# %%
graph.nodes()
# Out:
# ['1bilink2', 1, 2]

# %%
graph.edges()
# Out:
# [('1bilink2', 1), ('1bilink2', 2)]

# %%
graph.add_gaussian_to_leaves([1,2],a=0,b=5)

# %%
graph.create_gaussian_leaves(['B','C'],a=0,b=5)

# %%
graph.nx_graph.nodes(data=1)
# Out:
# [('1bilink2', {}),
#  (1, {'attr_name': 0.4857427227937111}),
#  (2, {'attr_name': 4.735945528849634}),
#  ('B', {'attr_name': 4.662736200723862}),
#  ('C', {'attr_name': 2.3085676358863467})]

# %%
graph.nx_graph.edges()
# Out:
# [('1bilink2', 1), ('1bilink2', 2)]

# %%
B=[1,2]

# %%
B[::-1][0]
# Out:
# 2

# %%
g=generate_binary_gaussian_tree(4)

# %%
g2=nx.convert_node_labels_to_integers(g.nx_graph)

# %%
g2.nodes(data=1)
# Out:
# [(0, {'attr_name': 2.5634635599223388}),
#  (1, {'attr_name': 9.489637844552245}),
#  (2, {}),
#  (3, {'attr_name': 1.2225163148189928}),
#  (4, {}),
#  (5, {'attr_name': 0.013056055251502996}),
#  (6, {}),
#  (7, {'attr_name': 7.878537915413268}),
#  (8, {}),
#  (9, {}),
#  (10, {}),
#  (11, {'attr_name': 8.322366511324777}),
#  (12, {'attr_name': 6.766404894253268}),
#  (13, {'attr_name': 6.7106729556042755}),
#  (14, {'attr_name': 7.383256796370874}),
#  (15, {'attr_name': 0.14582218880282827}),
#  (16, {}),
#  (17, {}),
#  (18, {}),
#  (19, {'attr_name': 9.718722219909228}),
#  (20, {'attr_name': 9.999841477507395}),
#  (21, {}),
#  (22, {'attr_name': 4.175061724645417}),
#  (23, {}),
#  (24, {}),
#  (25, {}),
#  (26, {'attr_name': 4.235953443517708}),
#  (27, {'attr_name': 4.59721978504289}),
#  (28, {}),
#  (29, {'attr_name': 0.5559598809961597}),
#  (30, {})]

# %%
D={max(g.nodes(), key=len):1}

# %%
g3=nx.relabel_nodes(g.nx_graph,D)

# %%
g3.nodes()
# Out:
# ['A6',
#  1,
#  'A3bilinkB0',
#  'A4',
#  'A7',
#  'A1',
#  'B3',
#  'A0bilinkB2',
#  'B0',
#  'A3bilinkB0bilinkA2bilinkB6',
#  'B2',
#  'A1bilinkB5bilinkA7bilinkB7',
#  'A6bilinkB1bilinkA4bilinkB4',
#  'B7',
#  'B5',
#  'A6bilinkB1',
#  'A5',
#  'A2',
#  'A4bilinkB4',
#  'B6',
#  'A5bilinkB3',
#  'A1bilinkB5',
#  'A0',
#  'B1',
#  'A3bilinkB0bilinkA2bilinkB6bilinkA6bilinkB1bilinkA4bilinkB4',
#  'A1bilinkB5bilinkA7bilinkB7bilinkA5bilinkB3bilinkA0bilinkB2',
#  'A5bilinkB3bilinkA0bilinkB2',
#  'A2bilinkB6',
#  'B4',
#  'A3',
#  'A7bilinkB7']

# %%
T=nx.bfs_tree(g3, 1)

# %%
g.display_graph(T,pos=g.hierarchy_pos(g3,1,rotate=True))

# %%
g.display_graph(g.nx_graph)
