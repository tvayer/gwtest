# %%
import numpy as np
import os,sys
#module_path = os.path.abspath(os.path.join('/Users/vayer/Documents/OT/Python/GW_tests/'))
#if module_path not in sys.path:
#    sys.path.append(module_path)
from graph import *
import copy
import NN,time

from ot_distances import Gromov_Wasserstein_distance,Gromov_distance,Wasserstein_distance


from ts import*

# %%
import numpy as np
import os,sys
from graph import *
import copy
import NN,time
from ot_distances import Gromov_Wasserstein_distance,Gromov_distance,Wasserstein_distance
from ts import*

# %%
path='./UCR_TS_Archive_2015/Lighting2/'

# %%
dataset=create_ts(path)

# %%
len(dataset)
# Out:
# 60

# %%
dataset[3][0].plot_ts(color='r')
dataset[2][0].plot_ts()
pl.show()

# %%
TS().plot_sample_ts_dataset(dataset,N=10,lw=10)

# %%
dist=Wasserstein_distance().ts_d

# %%
# %time
dist(dataset[0][0],dataset[36][0])
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.01 µs
# 0.0021151535508380954

# %%
plt.imshow(dataset[0][0].distance_matrix())
plt.show()

# %%
dist=Gromov_distance(epsilon=1,max_iter=12,method='time').ts_d

# %%
# %time
dist(dataset[0][0],dataset[36][0])
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.01 µs
# 0.078017983317746079

# %%
dist=Gromov_Wasserstein_distance(epsilon=1,ratio=0.5,method='time').ts_d

# %%
start=time.time()
dist(dataset[0][0],dataset[36][0])
end=time.time()

# %%
end-start
# Out:
# 0.29447388648986816

# %%
dataset[0][0].plot_ts(color='r')
dataset[36][0].plot_ts()
pl.legend([dataset[0][1],dataset[36][1]])
pl.show()

# %% [markdown]
# # Some tests

# %% [markdown]
# On est sur un problème à 5 classes.

# %%
path='./UCR_TS_Archive_2015/Lighting2/'

# %%
train=create_ts(path,t='TRAIN')
test=create_ts(path,t='TEST')

# %%
x_train,y_train=zip(*train)
x_test,y_test=zip(*test)

# %%
clf_wgw=NN.Ts_WGW_1NN_Classifier(epsilon=10,ratio=2.8,verbose=True,normalize_distance=True)

# %%
start=time.time()
clf_wgw.compute_similarity(x_train[0],x_train[1])
end=time.time()
print(end-start)
# Out:
# ...
# 0.413463830947876

# %%
len(x_train[0].values)
# Out:
# 637

# %%
len(train)
# Out:
# 60

# %%
len(test)
# Out:
# 61

# %%
0.6*181*77
# Out:
# 8362.199999999999

# %%
def compute():
    start=time.time()
    preds=clf_emd.fit(np.array(x_train),np.array(y_train)).predict(np.array(x_test))
    end=time.time()
    return end-start,preds

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold
import numpy as np
import os,sys
from graph import *
import copy
import NN,time
from ot_distances import Gromov_Wasserstein_distance,Gromov_distance,Wasserstein_distance
from ts import*

# %%
path='./UCR_TS_Archive_2015/Lighting2/'
train=create_ts(path,t='TRAIN')
test=create_ts(path,t='TEST')
x_train,y_train=zip(*train)
x_test,y_test=zip(*test)

# %%
n_jobs=1
n_splits=2

# %%
tuned_parameters = [{'epsilon':list(np.linspace(0.01,50,1)),
					 'ratio':list(np.linspace(0.01,2.5,1))
                     ,'method':['time']
                     ,'normalize_distance':[True]
                     ,'features_metric':['sqeuclidean']
                     ,'timedistance':['sqeuclidean']}]

# %%
wgw_1NN=NN.Ts_WGW_1NN_Classifier()
clf = GridSearchCV(wgw_1NN, tuned_parameters, cv=n_splits,scoring='accuracy',verbose=1,n_jobs=n_jobs)

# %%
clf.fit(np.array(x_train[0:4]).reshape(-1,1),np.array(y_train[0:4]))
# Out:
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Les distances entre pour chaque point et eux mêmes sont calculées
# //anaconda/lib/python3.5/site-packages/sklearn/model_selection/_split.py:581: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of groups for any class cannot be less than n_splits=2.
#   % (min_groups, self.n_splits)), Warning)
# Les distances entre pour chaque point et eux mêmes sont calculées
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.6s finished
# Les distances entre pour chaque point et eux mêmes sont calculées
# GridSearchCV(cv=2, error_score='raise',
#        estimator=Ts_WGW_1NN_Classifier(epsilon=1, features_metric='sqeuclidean', method='time',
#            normalize_distance=False, ratio=1, timedistance='sqeuclidean'),
#        fit_params={}, iid=True, n_jobs=1,
# ...

# %%
len(clf.best_estimator_.similarities_dict)
# Out:
# 4

# %%
clf.best_estimator_.similarities_dict
# Out:
# yo method
# {(<ts.TS at 0x11040f4a8>, <ts.TS at 0x11040f4a8>): 0.0014306890359211837,
#  (<ts.TS at 0x1103f1ac8>, <ts.TS at 0x1103f1ac8>): 0.0031318545314421862,
#  (<ts.TS at 0x1103f1a90>, <ts.TS at 0x1103f1a90>): 0.0036193050650708707,
#  (<ts.TS at 0x11040f470>, <ts.TS at 0x11040f470>): 0.0042054380904236041}

# %%
clf.predict(np.array(x_test)[0:2])
# Out:
# Ils sont diff  <ts.TS object at 0x10fcfd940> <ts.TS object at 0x10fcfdfd0> 0 0
# sheisse_xy entre  0 0
# sheisse_yy entre  0 0
# Ils sont diff  <ts.TS object at 0x10fcfd7f0> <ts.TS object at 0x10fcfdfd0> 1 0
# sheisse_xy entre  1 0
# Ils sont diff  <ts.TS object at 0x10fcfd978> <ts.TS object at 0x10fcfdfd0> 2 0
# sheisse_xy entre  2 0
# Ils sont diff  <ts.TS object at 0x10fcfd898> <ts.TS object at 0x10fcfdfd0> 3 0
# sheisse_xy entre  3 0
# Ils sont diff  <ts.TS object at 0x10fcfd940> <ts.TS object at 0x10fe5ff28> 0 1
# sheisse_xy entre  0 1
# sheisse_yy entre  0 0
# Ils sont diff  <ts.TS object at 0x10fcfd7f0> <ts.TS object at 0x10fe5ff28> 1 1
# sheisse_xy entre  1 1
# Ils sont diff  <ts.TS object at 0x10fcfd978> <ts.TS object at 0x10fe5ff28> 2 1
# sheisse_xy entre  2 1
# Ils sont diff  <ts.TS object at 0x10fcfd898> <ts.TS object at 0x10fe5ff28> 3 1
# sheisse_xy entre  3 1
# array([-1, -1])

# %%
clf.predict(np.array(x_test)[0:2])
# Out:
# Ils sont diff  <ts.TS object at 0x10fcfd940> <ts.TS object at 0x10fcfdfd0> 0 0
# Ils sont diff  <ts.TS object at 0x10fcfd7f0> <ts.TS object at 0x10fcfdfd0> 1 0
# Ils sont diff  <ts.TS object at 0x10fcfd978> <ts.TS object at 0x10fcfdfd0> 2 0
# Ils sont diff  <ts.TS object at 0x10fcfd898> <ts.TS object at 0x10fcfdfd0> 3 0
# Ils sont diff  <ts.TS object at 0x10fcfd940> <ts.TS object at 0x10fe5ff28> 0 1
# Ils sont diff  <ts.TS object at 0x10fcfd7f0> <ts.TS object at 0x10fe5ff28> 1 1
# Ils sont diff  <ts.TS object at 0x10fcfd978> <ts.TS object at 0x10fe5ff28> 2 1
# Ils sont diff  <ts.TS object at 0x10fcfd898> <ts.TS object at 0x10fe5ff28> 3 1
# array([-1, -1])

# %%
clf.best_estimator_.predict(np.array(x_test)[0:2])
# Out:
# Ils sont diff  <ts.TS object at 0x10fcfd940> <ts.TS object at 0x10fcfdfd0> 0 0
# Ils sont diff  <ts.TS object at 0x10fcfd7f0> <ts.TS object at 0x10fcfdfd0> 1 0
# Ils sont diff  <ts.TS object at 0x10fcfd978> <ts.TS object at 0x10fcfdfd0> 2 0
# Ils sont diff  <ts.TS object at 0x10fcfd898> <ts.TS object at 0x10fcfdfd0> 3 0
# Ils sont diff  <ts.TS object at 0x10fcfd940> <ts.TS object at 0x10fe5ff28> 0 1
# Ils sont diff  <ts.TS object at 0x10fcfd7f0> <ts.TS object at 0x10fe5ff28> 1 1
# Ils sont diff  <ts.TS object at 0x10fcfd978> <ts.TS object at 0x10fe5ff28> 2 1
# Ils sont diff  <ts.TS object at 0x10fcfd898> <ts.TS object at 0x10fe5ff28> 3 1
# array([-1, -1])

# %%
len(clf.best_estimator_.similarities_dict)
# Out:
# 14

# %%
wgw_1NN=NN.Ts_WGW_1NN_Classifier(**clf.best_params_)

# %%
wgw_1NN.fit(np.array(x_train[0:4]).reshape(-1,1),np.array(y_train[0:4])).predict(np.array(x_test)[0:4])
# Out:
# Les distances entre pour chaque point et eux mêmes sont calculées
# array([-1, -1, -1,  1])

# %%
x_train[0]==x_train[0]
# Out:
# yo method
# True

# %%
x_train[0]

# %%
clf.best_params_
# Out:
# {'epsilon': 0.01,
#  'features_metric': 'sqeuclidean',
#  'method': 'time',
#  'normalize_distance': True,
#  'ratio': 0.01,
#  'timedistance': 'sqeuclidean'}

# %%
nTree=100
depth=3
c=20
d=30
dataset=build_binary_uniform_dataset(nTree1=nTree,nTree2=nTree,maxdepth=depth,c=c,d=d)
X,y=zip(*dataset)

# %%
graph1=X[0]
graph2=X[101]

# %%
gw=Gromov_Wasserstein_distance(epsilon=0.01,ratio=0.01,method='weighted_shortest_path')

# %%
cpts=[]
temps=[]
i=0
N=10
espilons=list(np.linspace(0.01,150,5))
ratios=list(np.linspace(0.001,0.5,5))
for i in range(N):
    for eps in espilons:
        for ra in ratios:
    #for eps,ra in zip(espilons,ratios):
        
            graph1=X[random.randint(0,len(X)-1)]
            graph2=X[random.randint(0,len(X)-1)]
            start=time.time()
            a=gw.graph_d(graph1,graph2)
            end=time.time()
            cpts.append(gw.log['cpt'])
            temps.append(end-start)

# %%
plt.plot(cpts)
plt.show()

# %%
plt.plot(temps)
plt.show()

# %%
max(cpts)
# Out:
# 3

# %%
import numpy as np
import os,sys
from graph import *
from ts import *
import copy
import NN,time
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold
from WGW_3 import WGW

# %%
path='./UCR_TS_Archive_2015/Lighting2/'
train=create_ts(path,t='TRAIN')
test=create_ts(path,t='TEST')
x_train,y_train=zip(*train)
x_test,y_test=zip(*test)

# %%
size=50
train=create_random_ts(N=size,a=0,b=300)
test=create_random_ts(N=size,a=0,b=300)
x_train,y_train=zip(*train)
x_test,y_test=zip(*test)

# %%
from ot_distances import Gromov_distance as GW

# %%
ts1=x_train[0]
ts2=x_train[1]
C1=ts1.distance_matrix(method='time')
C2=ts2.distance_matrix(method='time')

t1masses = np.ones(len(ts1.values))/len(ts1.values)
t2masses = np.ones(len(ts2.values))/len(ts2.values)
w=WGW(np.zeros((C1.shape[0],C2.shape[0])),C1,C2,t1masses,t2masses,15,1)

# %%
def main(N=50):
    import ot
    import numpy as np
    size=N
    x1=list(np.random.uniform(low=0, high=300, size=(N,)))
    times1=range(len(x1))
    x2=list(np.random.uniform(low=0, high=300, size=(N,)))
    times2=range(len(x2))
    t1masses = np.ones(len(x1))/len(x1)
    t2masses = np.ones(len(x2))/len(x2)
    C=ot.dist(np.array(times1).reshape(-1,1),np.array(times1).reshape(-1,1))
    for i  in range(1000000):
        c=ot.sinkhorn(t1masses,t2masses,C,10,verbose=False)

# %%
#tens = w.constC-np.dot(w.hC1, w.T).dot(w.hC2.T)
#Cost = w.G+w.alpha*tens
for i  in range(1000000):
    #gw=GW(epsilon=15,method='time')
    #d=gw.ts_d(x_train[0],x_train[1])
    c=ot.sinkhorn(t1masses,t2masses,C1,10,verbose=False)
    #transpwgw,log= wgw.wgw(np.zeros((C1.shape[0],C2.shape[0])),C1,C2,t1masses,t2masses,'square_loss',15,alpha=1,max_iter=500,verbose=False,log=True)
    #transpwgw,log=w.wgw(log=True)
    #tens = w.constC-np.dot(w.hC1, w.T).dot(np.transpose(w.hC2))
    #tens = w.constC
    #tens =np.dot(w.hC1, w.T).dot(np.transpose(w.hC2))


    #Cost = w.G+w.alpha*tens

    #T = ot.sinkhorn(w.p, w.q, Cost, w.epsilon, numItermax=100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-74c75d050d9c> in <module>()
#       9     #tens = w.constC-np.dot(w.hC1, w.T).dot(np.transpose(w.hC2))
#      10     #tens = w.constC
# ---> 11     tens =np.dot(w.hC1, w.T).dot(np.transpose(w.hC2))
#      12
#      13
#
# KeyboardInterrupt:

# %%
N=600
A=np.ones((N,N))
B=np.ones((N,N))
for i  in range(10000):
    tens =np.dot(A, B.T)
    del tens
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-f9bf17da38cd> in <module>()
#       3 B=np.ones((N,N))
#       4 for i  in range(10000):
# ----> 5     tens =np.dot(A, B.T)
#       6     del tens
#       7
#
# KeyboardInterrupt:

# %%
x_train[1]

# %%
dir_path='./'
result_file='result_grid_lightning_WGW_test.csv'
text_file = open(os.path.join(dir_path, result_file), 'w')

n_splits=5
n_jobs=1
start_time = time.time()

print('CV Nb_splits : ', n_splits, file=text_file)
print('Data train size : ',len(x_train),file=text_file)
print('Data test size : ',len(x_train),file=text_file)
print('N_jobs : ',n_jobs,file=text_file)


#tuned_parameters = [{'epsilon':list(np.linspace(0.01,50,5)),
#					 'ratio':list(np.linspace(0.01,2.5,5))
#                    ,'method':['time']
#                     ,'normalize_distance':[False,True]
#                     ,'features_metric':['sqeuclidean']
#                     ,'timedistance':['sqeuclidean']}]

tuned_parameters = [{'epsilon':list(np.linspace(15,50,1)),'method':['time']
                     ,'normalize_distance':[True]
                     ,'timedistance':['sqeuclidean']}]

print('Tuned tuned_parameters : ',tuned_parameters,file=text_file) 

wgw_1NN=NN.Ts_GW_1NN_Classifier()
clf = GridSearchCV(wgw_1NN, tuned_parameters, cv=n_splits,scoring='accuracy',verbose=1)
clf.fit(np.array(x_train).reshape(-1,1),np.array(y_train))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Construction des matrices de structures
# Les distances entre pour chaque point et eux mêmes sont calculées
# Construction des matrices de structures
# Les distances entre pour chaque point et eux mêmes sont calculées
# Construction des matrices de structures
# Les distances entre pour chaque point et eux mêmes sont calculées
# Construction des matrices de structures
# Les distances entre pour chaque point et eux mêmes sont calculées
# Construction des matrices de structures
# Les distances entre pour chaque point et eux mêmes sont calculées
# Construction des matrices de structures
# Les distances entre pour chaque point et eux mêmes sont calculées
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   13.4s finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=Ts_GW_1NN_Classifier(epsilon=1, method='time', normalize_distance=False,
#            timedistance='sqeuclidean'),
# ...

# %%
import numpy as np
import os,sys
from graph import *
from ts import *
import copy
import NN,time
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold

path='./UCR_TS_Archive_2015/Lighting2/'
train=create_ts(path,t='TRAIN')
test=create_ts(path,t='TEST')
x_train,y_train=zip(*train)
x_test,y_test=zip(*test)

dir_path='./'
result_file='result_grid_lightning_WGW_test.csv'
text_file = open(os.path.join(dir_path, result_file), 'w')

n_splits=5
n_jobs=1
start_time = time.time()

print('CV Nb_splits : ', n_splits, file=text_file)
print('Data train size : ',len(x_train),file=text_file)
print('Data test size : ',len(x_train),file=text_file)
print('N_jobs : ',n_jobs,file=text_file)


#tuned_parameters = [{'epsilon':list(np.linspace(0.01,50,5)),
#					 'ratio':list(np.linspace(0.01,2.5,5))
#                    ,'method':['time']
#                     ,'normalize_distance':[False,True]
#                     ,'features_metric':['sqeuclidean']
#                     ,'timedistance':['sqeuclidean']}]

tuned_parameters = [{'features_metric':['sqeuclidean']}]

print('Tuned tuned_parameters : ',tuned_parameters,file=text_file) 

wgw_1NN=NN.Ts_EMD_1NN_Classifier()
clf = GridSearchCV(wgw_1NN, tuned_parameters, cv=n_splits,scoring='accuracy',verbose=1,n_jobs=n_jobs)
clf.fit(np.array(x_train).reshape(-1,1),np.array(y_train))


print('--------------------------', file=text_file)
print('--------------------------', file=text_file)
print('', file=text_file)
print("Best parameters set found on development set:", file=text_file)
print('', file=text_file)
print(clf.best_params_, file=text_file)
print('', file=text_file)
print('--------------------------', file=text_file)
print('--------------------------', file=text_file)
print("Grid scores on development set:", file=text_file)
print('', file=text_file)
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r"
        % (mean, std * 2, params), file=text_file)
print('', file=text_file)


end_time = time.time()
print('--------------------------', file=text_file)
print('--------------------------', file=text_file)

#nested_score = cross_val_score(clf, X=np.array(x_test), y=np.array(y_test)
#	,cv=n_splits,n_jobs=n_jobs,scoring='accuracy')
#nested_scores = nested_score.mean()
preds=clf.predict(np.array(x_test))
nested_scores=np.sum(preds==np.array(y_test))/len(y_test)

print('Score on test set with best_params_ : ',nested_scores,file=text_file)



print('All Time :', end_time-start_time, file=text_file)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-9fb0bc084e47> in <module>()
#      40 wgw_1NN=NN.Ts_EMD_1NN_Classifier()
#      41 clf = GridSearchCV(wgw_1NN, tuned_parameters, cv=n_splits,scoring='accuracy',verbose=1,n_jobs=n_jobs)
# ---> 42 clf.fit(np.array(x_train).reshape(-1,1),np.array(y_train))
#      43
#      44
#
# //anaconda/lib/python3.5/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups)
#     943             train/test set.
#     944         """
# --> 945         return self._fit(X, y, groups, ParameterGrid(self.param_grid))
#     946
#     947
#
# //anaconda/lib/python3.5/site-packages/sklearn/model_selection/_search.py in _fit(self, X, y, groups, parameter_iterable)
#     562                                   return_times=True, return_parameters=True,
# ...

# %%
emd_1NN=NN.Ts_EMD_1NN_Classifier()
wgw_1NN=NN.Ts_GW_1NN_Classifier(epsilon=15,method='time')

# %%
path='./UCR_TS_Archive_2015/Lighting2/'
train=create_ts(path,t='TRAIN')
test=create_ts(path,t='TEST')
x_train,y_train=zip(*train)
x_test,y_test=zip(*test)

# %%
for i in range(10000000):
    a=wgw_1NN.compute_similarity(x_train[0],x_train[1])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-2cb473030e66> in <module>()
#       1 for i in range(10000000):
# ----> 2     a=wgw_1NN.compute_similarity(x_train[0],x_train[1])
#
# /Users/vayer/Documents/OT/Python/GW_tests/NN.py in compute_similarity(self, x, y)
#     197                     self.similarities_dict[(x,x)]=self.similarity_measure(x,x)
#     198         else:
# --> 199             similarity=super(Normalized_1NN_Classifier,self).compute_similarity(x,y) # Attention
#     200
#     201         return similarity
#
# /Users/vayer/Documents/OT/Python/GW_tests/NN.py in compute_similarity(self, x, y)
#      23
#      24     def compute_similarity(self,x,y):
# ---> 25         if (x,y) in self.similarities_dict: # ou suppose que les similarités sont symétriques
#      26             similarity=self.similarities_dict[(x,y)]
# ...

# %%
emd_1NN.compute_similarity(x_train[0],x_train[1])
# Out:
# 0.0060392277187339685
