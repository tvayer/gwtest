# %% [markdown]
# ### Recherche des paramètres

# %%
import numpy as np
import os,sys
module_path = os.path.abspath(os.path.join('/Users/vayer/Documents/OT/Python/GW_tests/'))
if module_path not in sys.path:
    sys.path.append(module_path)
from graph import *
import copy
import NN,time
from sklearn.model_selection import StratifiedKFold
import ot_distances

# %%
path='./mutag/'

# %%
dataset_mutag=list(build_mutag_dataset(path))

# %%
dataset_toytrees=build_binary_uniform_dataset(nTree1=50,nTree2=50,maxdepth=3,c=20,d=30)

# %% [markdown]
# ### Pour trees

# %%
dataset_toytrees[0][0]

# %%
graph1=dataset_toytrees[0][0]
graph2=dataset_toytrees[1][0]

# %%
graph1.display_graph(pos=graph1.hierarchy_pos(graph1.nx_graph,1,rotate=True))

# %%
graph2.display_graph(pos=graph2.hierarchy_pos(graph2.nx_graph,1,rotate=True))

# %%
clf_emd=NN.Tree_EMD_1NN_Classifier()

# %%
clf_emd.compute_similarity(graph1,graph2)
# Out:
# 0.0016141022925251409

# %%
clf_GW=NN.Tree_GW_1NN_Classifier(epsilon=0.8,method='weighted_shortest_path')

# %%
clf_GW.compute_similarity(graph1,graph2)
# Out:
# 1.4515352181753749

# %% [markdown]
# Marche à partir de 0.8

# %%
clf_WGW=NN.Tree_WGW_1NN_Classifier(alpha=20,epsilon=10,method='weighted_shortest_path',features_metric='sqeuclidean')

# %%
clf_WGW.compute_similarity(graph1,graph2)
# Out:
# ...
# //anaconda/lib/python3.5/site-packages/ot/bregman.py:344: RuntimeWarning: overflow encountered in exp
#   K = np.exp(-M / reg)
# nan

# %% [markdown]
# On peut faire à partir de où on veut (rapport de 1 c'est good) mais va falloir qu'ils évoluent en même temps ? Il faut pas que alpha soit deux fois plus grand

# %%
np.max(graph1.distance_matrix(method='weighted_shortest_path'))
# Out:
# 8.0

# %%
dataset_toytrees=build_binary_uniform_dataset(nTree1=10,nTree2=10,maxdepth=3,c=20,d=30)

# %%
X,y=zip(*dataset_toytrees)

# %%
clf_GW.fit(np.array(X),np.array(y))

# %%
preds=clf_GW.predict(np.array(X))
# Out:
# //anaconda/lib/python3.5/site-packages/ot/bregman.py:344: RuntimeWarning: overflow encountered in exp
#   K = np.exp(-M / reg)
# ...

# %%
import seaborn as sns
sns.heatmap(clf_GW.similarities,xticklabels=False,yticklabels=False)
plt.title('Similarités : distances entre les points en ordonnant suivant la classe ')
plt.xlabel('Arbres')
plt.ylabel('Arbres')
plt.show()
